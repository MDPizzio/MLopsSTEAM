# %%
#Importamos librerias y ponemos las rutas de los datasets

import pandas as pd
import gzip
import ast
from datetime import datetime
import calendar
import re

path1 = '/Users/MaxiPizzio/Desktop/PI MLOps - STEAM/steam_games.json.gz'
path2 = '/Users/MaxiPizzio/Desktop/PI MLOps - STEAM/users_items.json.gz'
path3 = '/Users/MaxiPizzio/Desktop/PI MLOps - STEAM/user_reviews.json.gz'

# %%
#Abrimos el dataset 

with gzip.open(path1, 'rt', encoding='utf-8') as f:
    df_games = pd.read_json(f, lines=True)

# %%
#Generamos la funcion para poder leer los otros dos datasets

def leer_json_gzip(file) :
    with gzip.open(file, 'rt', encoding='utf-8') as miArchivo:
        return [ast.literal_eval(line.strip()) for line in miArchivo]

# %%
#Generamos la funcion para desanidar las columnas items y reviews
def de_nest_items(df):
    items = df['items'].explode()
    df = df.drop('items', axis=1)
    df = df.join(items.apply(pd.Series))
    return df

# %%
#Leemos el dataset
datos_items = leer_json_gzip(path2)
df_items = pd.DataFrame(datos_items)

# %%
#Leemos un elemento del dataset para ver la estructura anidada
df_items_1 = df_items.sample(1)
for item in df_items_1['items']:
    print(item)
# Out:
# [{'item_id': '4000', 'item_name': "Garry's Mod", 'playtime_forever': 23275, 'playtime_2weeks': 0}, {'item_id': '42120', 'item_name': 'Lead and Gold - Gangs of the Wild West', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '12210', 'item_name': 'Grand Theft Auto IV', 'playtime_forever': 4427, 'playtime_2weeks': 0}, {'item_id': '12220', 'item_name': 'Grand Theft Auto: Episodes from Liberty City', 'playtime_forever': 1622, 'playtime_2weeks': 0}, {'item_id': '620', 'item_name': 'Portal 2', 'playtime_forever': 610, 'playtime_2weeks': 0}, {'item_id': '2400', 'item_name': 'The Ship', 'playtime_forever': 66, 'playtime_2weeks': 0}, {'item_id': '2420', 'item_name': 'The Ship Single Player', 'playtime_forever': 495, 'playtime_2weeks': 0}, {'item_id': '2430', 'item_name': 'The Ship Tutorial', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '51100', 'item_name': 'Tactical Intervention', 'playtime_forever': 214, 'playtime_2weeks': 0}, {'item_id': '243870', 'item_name': "Tom Cl
# ...

# %%
#Desanidamos la columna items 
items = df_items['items'].explode()
df_items = df_items.drop('items', axis=1)
df_items = df_items.join(items.apply(pd.Series))

# %%
#Vemos nuevamente el dataset para entender su estructura
df_items
# Out:
#                  user_id  items_count           steam_id  \
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# ...                  ...          ...                ...
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88309  edward_tremethick            0  76561198331598578
#
#                                                 user_url item_id  \
# 0      http://steamcommunity.com/profiles/76561197970...      10
# 0      http://steamcommunity.com/profiles/76561197970...      20
# 0      http://steamcommunity.com/profiles/76561197970...      30
# ...

# %%
#Guardamos el archivo asi no tenemos que volver a esperar 40 min

df_items_exploded = df_items.to_parquet("df_items_exploded.parquet", index=False)

# %%
df_items
# Out:
#                  user_id  items_count           steam_id  \
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# 0      76561197970982479          277  76561197970982479
# ...                  ...          ...                ...
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88308  76561198329548331            7  76561198329548331
# 88309  edward_tremethick            0  76561198331598578
#
#                                                 user_url item_id  \
# 0      http://steamcommunity.com/profiles/76561197970...      10
# 0      http://steamcommunity.com/profiles/76561197970...      20
# 0      http://steamcommunity.com/profiles/76561197970...      30
# ...

# %%
#Dropeamos las columnas innecesarias para el EDA y para las posteriores funciones
df_items.drop([0,'steam_id','playtime_2weeks','user_url','items_count'], axis=1, inplace=True)

# %%
df_items
# Out:
#                  user_id item_id                      item_name  \
# 0      76561197970982479      10                 Counter-Strike
# 0      76561197970982479      20          Team Fortress Classic
# 0      76561197970982479      30                  Day of Defeat
# 0      76561197970982479      40             Deathmatch Classic
# 0      76561197970982479      50      Half-Life: Opposing Force
# ...                  ...     ...                            ...
# 88308  76561198329548331  373330                    All Is Dust
# 88308  76561198329548331  388490  One Way To Die: Steam Edition
# 88308  76561198329548331  521570          You Have 10 Seconds 2
# 88308  76561198329548331  519140                     Minds Eyes
# 88309  edward_tremethick     NaN                            NaN
#
#        playtime_forever
# 0                   6.0
# 0                   0.0
# 0                   7.0
# 0                   0.0
# 0                   0.0
# ...                 ...
# ...

# %%
#Dropeamos las filas que tengan todos nulos
df_items.dropna(how='all', inplace=True)

# %%
#Dropeamos los duplicados
df_items=df_items.drop_duplicates()

# %%
#Dropeamos las filas que tengan valores nulos en las columnas que necesitaremos para hacer las funciones
df_items.dropna(subset=['playtime_forever'],inplace=True)
df_items.dropna(subset=['item_id'],inplace=True)
df_items.dropna(subset=['user_id'],inplace=True)

# %%
df_items
# Out:
#                  user_id item_id                      item_name  \
# 0      76561197970982479      10                 Counter-Strike
# 0      76561197970982479      20          Team Fortress Classic
# 0      76561197970982479      30                  Day of Defeat
# 0      76561197970982479      40             Deathmatch Classic
# 0      76561197970982479      50      Half-Life: Opposing Force
# ...                  ...     ...                            ...
# 88308  76561198329548331  346330                   BrainBread 2
# 88308  76561198329548331  373330                    All Is Dust
# 88308  76561198329548331  388490  One Way To Die: Steam Edition
# 88308  76561198329548331  521570          You Have 10 Seconds 2
# 88308  76561198329548331  519140                     Minds Eyes
#
#        playtime_forever
# 0                   6.0
# 0                   0.0
# 0                   7.0
# 0                   0.0
# 0                   0.0
# ...                 ...
# ...

# %%
#Buscamos la info para ver cuanto pesa y los tipos de datos 
df_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5094092 entries, 0 to 5110804
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           object
#  1   items_count       int64
#  2   item_id           object
#  3   item_name         object
#  4   playtime_forever  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 233.2+ MB

# %%
#Guardamos el archivo
df_items_data = df_items.to_parquet("df_items_data.parquet", index=False)

# %%
#Creamos un sample del dataframe items ya que es demasiado grande para RENDER 
df_items_sample = df_items.sample(50000)
df_items_sample.to_parquet("df_items_sample.parquet", index=False)

# %%
#Leemos el ultimo dataset
datos_reviews = leer_json_gzip(path3)
df_reviews = pd.DataFrame(datos_reviews)

# %%
df_reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
#Se importa la librería a usar (posterior a la instalación del paquete TextBlob) para realizar el análisis de sentimientos
from textblob import TextBlob

# %%
#Se crea la función para realizar el análisis de sentimientos
def sentiment_analysis(review):
    if isinstance(review, list) and len(review) > 0:
        text = review[0].get('review', '')
        sentiment = TextBlob(text).sentiment.polarity
        
        if sentiment < -0.2:
            return 0 # Negativo
        elif sentiment >= -0.2 and sentiment <= 0.2:
            return 1 # Neutral
        else:
            return 2 # Positivo
    else:
        return 1 # Valor para casos en que la reseña escrita este ausente

# %%
#Aplicamos la funcion al dataframe y generamos una nueva columna
df_reviews['sentiment_analysis'] = df_reviews['reviews'].apply(sentiment_analysis)

# %%
df_reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
# ...

# %%
# Usamos explode() para desanidar las revisiones
df_reviews_aux = df_reviews.explode('reviews')

# Convertimos la columna 'reviews' en un DataFrame
df_reviews_aux = pd.concat([df_reviews_aux.drop(['reviews'], axis=1), df_reviews_aux['reviews'].apply(pd.Series)], axis=1)


df_reviews_aux
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 1                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
# ...

# %%
#Dropeamos las columnas que no son pertinentes para el EDA y para las funciones
df_reviews_aux.drop([0,'helpful','funny','last_edited','review','user_url'], axis=1, inplace=True)

# %%
df_reviews_aux
# Out:
#                  user_id  sentiment_analysis                     posted  \
# 0      76561197970982479                   1   Posted November 5, 2011.
# 0      76561197970982479                   1      Posted July 15, 2011.
# 0      76561197970982479                   1     Posted April 21, 2011.
# 1                js41637                   1      Posted June 24, 2014.
# 1                js41637                   1  Posted September 8, 2013.
# ...                  ...                 ...                        ...
# 25797  76561198312638244                   2            Posted July 10.
# 25797  76561198312638244                   2             Posted July 8.
# 25798        LydiaMorley                   1             Posted July 3.
# 25798        LydiaMorley                   1            Posted July 20.
# 25798        LydiaMorley                   1             Posted July 2.
#
#       item_id recommend
# 0        1250      True
# 0       22200      True
# 0       43110      True
# ...

# %%
#Dropeamos aquellas filas que tengan solo nulos
df_reviews_aux.dropna(axis=0, how='all',inplace=True)

# %%
#Dropeamos duplicados
df_reviews_aux2 = df_reviews_aux.drop_duplicates()

# %%
#Creamos la funcion para cxtraer de la columna posted solo el año que sera util para el EDA y las funciones

def extract_year(date_str):
    if pd.notna(date_str) and isinstance(date_str, str):
        # Usamos expresiones regulares para extraer el año
        match = re.match(r'Posted .* (\d{4})', date_str)
        if match:
            year = match.group(1)
            return int(year)
    return pd.NaT  # Devolvemos nulo si no coincide el formato

# %%
df_reviews_aux2['posted'] = df_reviews_aux2['posted'].apply(extract_year)
df_reviews_aux2
# Out:
# /var/folders/xn/r_jyrsz564j9ql0gmgs3n8fw0000gq/T/ipykernel_18062/461629194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reviews_aux2['posted'] = df_reviews_aux2['posted'].apply(extract_year)
#                  user_id  sentiment_analysis posted item_id recommend
# 0      76561197970982479                   1   2011    1250      True
# 0      76561197970982479                   1   2011   22200      True
# 0      76561197970982479                   1   2011   43110      True
# 1                js41637                   1   2014  251610      True
# 1                js41637                   1   2013  227300      True
# ...                  ...                 ...    ...     ...       ...
# ...

# %%
#Dropeamos los nulos resultantes de aplicar la funcion extract year
df_reviews_aux2.dropna(subset={'posted'}, inplace=True)

df_reviews_aux2
# Out:
# /var/folders/xn/r_jyrsz564j9ql0gmgs3n8fw0000gq/T/ipykernel_18062/2246242366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reviews_aux2.dropna(subset={'posted'}, inplace=True)
#                  user_id  sentiment_analysis posted item_id recommend
# 0      76561197970982479                   1   2011    1250      True
# 0      76561197970982479                   1   2011   22200      True
# 0      76561197970982479                   1   2011   43110      True
# 1                js41637                   1   2014  251610      True
# 1                js41637                   1   2013  227300      True
# ...                  ...                 ...    ...     ...       ...
# 25764            wayfeng                   1   2015     730      True
# ...

# %%
#Revisamos la info para ver los tipos de datos y cuanto pesa el archivo
df_reviews_aux2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48498 entries, 0 to 25780
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             48498 non-null  object
#  1   sentiment_analysis  48498 non-null  int64
#  2   posted              48498 non-null  object
#  3   item_id             48498 non-null  object
#  4   recommend           48498 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ MB

# %%
#Guardamos el archivo
df_reviews_data = df_reviews_aux2.to_csv("df_reviews_data.csv", index=False)

# %%
#Visualizamos el dataset de juegos
df_games
# Out:
#               publisher                                 genres  \
# 0                  None                                   None
# 1                  None                                   None
# 2                  None                                   None
# 3                  None                                   None
# 4                  None                                   None
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444             None                                   None
#
#                         app_name                     title  \
# 0                           None                      None
# 1                           None                      None
# ...

# %%
#Dropeamos filas que tengan solo nulos
df_games.dropna(axis=0, how='all',inplace=True)
# Out:
# Dropeamos filas que tengan solo nulos

# %%
#Dropeamos las columnas que no consideramos pertinentes para el posterior EDA y las funciones
df_games.drop(['publisher','url','reviews_url','price','early_access','developer','specs'],axis=1,inplace=True)

# %%
df_games
# Out:
#                                                   genres  \
# 0          [Action, Casual, Indie, Simulation, Strategy]
# 1                   [Free to Play, Indie, RPG, Strategy]
# 2      [Casual, Free to Play, Indie, Simulation, Sports]
# 3                            [Action, Adventure, Casual]
# 4                                                   None
# ...                                                  ...
# 32130              [Casual, Indie, Simulation, Strategy]
# 32131                          [Casual, Indie, Strategy]
# 32132                        [Indie, Racing, Simulation]
# 32133                                    [Casual, Indie]
# 32134                                               None
#
#                        app_name                     title release_date  \
# 0           Lost Summoner Kitty       Lost Summoner Kitty   2018-01-04
# 1                     Ironbound                 Ironbound   2018-01-04
# ...

# %%
#Dropeamos los juegos duplicados usando su id
df_games.drop_duplicates(subset=['id'], inplace=True)

# %%
#Dropeamos los juegos que no tengan ni genero ni tags, o ni appname ni title ya que solo entorpeceran el EDA  y las funciones
df_games.dropna(subset=['genres','tags'],how='all', inplace=True)
df_games.dropna(subset=['app_name','title'],how='all', inplace=True)

# %%
df_games
# Out:
#                                                   genres  \
# 0          [Action, Casual, Indie, Simulation, Strategy]
# 1                   [Free to Play, Indie, RPG, Strategy]
# 2      [Casual, Free to Play, Indie, Simulation, Sports]
# 3                            [Action, Adventure, Casual]
# 4                                                   None
# ...                                                  ...
# 32130              [Casual, Indie, Simulation, Strategy]
# 32131                          [Casual, Indie, Strategy]
# 32132                        [Indie, Racing, Simulation]
# 32133                                    [Casual, Indie]
# 32134                                               None
#
#                        app_name                     title release_date  \
# 0           Lost Summoner Kitty       Lost Summoner Kitty   2018-01-04
# 1                     Ironbound                 Ironbound   2018-01-04
# ...

# %%
#Convertimos en entero la columna id para poder hacer un mejor manejo de datos
df_games['id'] = df_games['id'].astype(int)

# %%
# Función para extraer el año de la fecha 
def extract_year(date_str):
    try:
        return pd.to_datetime(date_str, errors='coerce').year
    except:
        return None

# Aplicar la función para extraer solo el año ya que es lo mejor para el EDA y las funciones, los dias y meses no son requeridos
df_games['release_date'] = df_games['release_date'].apply(extract_year)

# Filtrar filas sin año válido
df_games.dropna(subset=['release_date'],how='all', inplace=True)

df_games['release_date'] = df_games['release_date'].astype(int)


df_games
# Out:
# /var/folders/xn/r_jyrsz564j9ql0gmgs3n8fw0000gq/T/ipykernel_18062/3346178708.py:4: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   return pd.to_datetime(date_str, errors='coerce').year
#                     genres                                           app_name  \
# 1425              [Action]               Bioshock Infinite: Columbia's Finest
# 30524  [Action, Adventure]                  Assassin’s Creed® III Season Pass
# 30322             [Action]            Call of Duty®: Black Ops II Season Pass
# 30689           [Strategy]                       Worms Revolution Season Pass
# 30593             [Action]  Tom Clancy's Ghost Recon Future Soldier - Seas...
# ...                    ...                                                ...
# 32104             [Action]                          Half-Life: Opposing Force
# ...

# %%
df_games
# Out:
#                     genres                                           app_name  \
# 1425              [Action]               Bioshock Infinite: Columbia's Finest
# 30524  [Action, Adventure]                  Assassin’s Creed® III Season Pass
# 30322             [Action]            Call of Duty®: Black Ops II Season Pass
# 30689           [Strategy]                       Worms Revolution Season Pass
# 30593             [Action]  Tom Clancy's Ghost Recon Future Soldier - Seas...
# ...                    ...                                                ...
# 32104             [Action]                          Half-Life: Opposing Force
# 32108             [Action]                                 Deathmatch Classic
# 32114             [Action]                                      Day of Defeat
# 32103             [Action]                              Team Fortress Classic
# 32106             [Action]                                     Counter-Strike
#
# ...

# %%
#Visualizamos el dataset para ver sus tipos de datos y su peso de archivo.
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29754 entries, 1425 to 32106
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   genres        28657 non-null  object
#  1   app_name      29754 non-null  object
#  2   title         29754 non-null  object
#  3   release_date  29754 non-null  int64
#  4   tags          29730 non-null  object
#  5   id            29754 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 1.6+ MB

# %%
#Guardamos el archivo
df_games_data = df_games.to_csv('df_games_data.csv', index=False)
